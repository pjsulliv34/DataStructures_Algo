# %%
# # Import Expressions class
# from Lab2.expressions import Expressions


# This method will process the input file based on input type and desired output type and then output
# the data into the output file at the desired location


def process_input_file(input, freq_table = False, Encode = True):
    
    # Initialize and Empty list
    Processed_data = []

    # Open up the input file in reader mode
    with open(input,'r') as reader:

        # While loop that will stay open until the break close below
        while True:

            # Read in the first line and strip white space from the right and left
            line = reader.readline().strip()

            # Replace any white space in between operators and characters with emtpy string
            line = line.replace(' ', '')

            # Replace carrot operator with desired $
            line = line.replace('^','$')

            # Clause to check if the line is empty, if so break the while loop
            if line == '':
                break
                
            # Try clause to process the line in the input file
            if freq_table:
                try:
                    #print(line)
                    split = line.split('-')
                    Processed_data.append([split[0],int(split[1])])
                except Exception as e:
                    print(e)
            elif Encode:
                try:
                    print(line)
                except Exception as e:
                        print(e)
            else:
                pass # proccess for decoding
        if freq_table:
            return Processed_data
                # Create an expression object using the Expressions Class
                
    #             expression_object = Expressions(line,input_type)
                
    #             # If Else clause to check what is the desired output. Desired output will determine which clause to run
    #             if output_type == 'Postfix':
                    
    #                 # Create desired output string using expression object method
    #                 output_expression = expression_object.to_post_fix()

    #                 # Append Input and output to the processed data list
    #                 Processed_data.append([line,output_expression])

    #             elif output_type == 'Prefix':
    #                 output_expression = expression_object.to_pre_fix()
    #                 Processed_data.append([line,output_expression])
    #             else:
    #                 output_expression = expression_object.to_infix()
    #                 Processed_data.append([line,output_expression])

    #         # Except clause to catch any errors that are not planned
    #         except Exception as e:
    #             print(e)
    #             Processed_data.append([line,e])
                     
    # # Open up output file in writing mode
    # with open(output, 'w') as writer:

    #     # Initialize Index at 1
    #     index = 1

    #     # Loop through process data list
        # for line in Processed_data:

        #     # Write to the output file using the write method and fstring
        #     writer.write(f"Testcase {index}\n {input_type}: {line[0]}\n {output_type}: {line[1]}\n")

        #     # Increment index by 1
        #     index +=1

# %%
class HuffmanEncoding:
    def __init__(self,freqency_table: list):
        self.frequency_table = freqency_table


    def create_priority_queue(self):
        print(self.frequency_table)

class TreeNode:
    def __init__(self,data, left = None, right = None):
        self.data = data
        self.left = left
        self.right = right


    def create_priority_queue(self):
        print(self.frequency_table)

class BinarySearchTree:
    def __init__(self,unsorted_list):
        self.unsorted_list = unsorted_list

        # This will be the current node in 
        self.root = None

    def create_binary_search_tree(self):
        binarysearchtree = []
        #[print(value) for key,value in self.unsorted_list]
        for value in self.unsorted_list:
            self.insert_value(value)

    def insert_value(self, value):
        if self.root == None:
            self.root = TreeNode(value)
        else:
            if value < self.root:
                if self.root.left is None:
                    self.root.left = value
                else:
                    self.root.left 
                    self.insert_value(self,value, )

# %%
class TreeNode:
    def __init__(self,data, left = None, right = None):
        self.data = data
        self.left = left
        self.right = right


class BinarySearchTree:
    def __init__(self, unsorted_list):
        self.unsorted_list = unsorted_list
        self.root = None
        self.tree_list = []

    def create_binary_search_tree(self):
        for value in self.unsorted_list:
            self.insert_value(value)

    def insert_value(self, value):
        node = TreeNode(value)
        if self.root is None:
            self.root = node
        else:
            current_node = self.root
            while True:
                if value < current_node.data:
                    if current_node.left is None:
                        current_node.left = node
                        break
                    else:
                        current_node = current_node.left
                else:
                    if current_node.right is None:
                        current_node.right = node
                        break
                    else:
                        current_node = current_node.right
        self.tree_list.append(node)

# %%
x = process_input_file(r'../resources/FreqTable.txt', freq_table= True)
# Huffman_object = HuffmanEncoding(x)
# Huffman_object.create_priority_queue()

# bst = BinarySearchTree(x)
# bst.create_binary_search_tree()
# list_ = bst.tree_list
# for i in list_:
#     print(i.data), print(i.left), print(i.right)
# Out:
# ['A', 19]
# None
# <__main__.TreeNode object at 0x0000026487423AA0>
# ['B', 16]
# None
# <__main__.TreeNode object at 0x00000264875B37A0>
# ['C', 17]
# None
# <__main__.TreeNode object at 0x000002648741D3D0>
# ['D', 11]
# None
# <__main__.TreeNode object at 0x000002648741C680>
# ['E', 42]
# None
# <__main__.TreeNode object at 0x00000264875CD670>
# ['F', 12]
# None
# <__main__.TreeNode object at 0x00000264875CDD90>
# ['G', 14]
# None
# <__main__.TreeNode object at 0x00000264875CDAC0>
# ['H', 17]
# None
# <__main__.TreeNode object at 0x00000264875CD610>
# ['I', 16]
# None
# <__main__.TreeNode object at 0x00000264875CCA10>
# ['J', 5]
# None
# <__main__.TreeNode object at 0x00000264875CE3C0>
# ['K', 10]
# None
# <__main__.TreeNode object at 0x00000264875CFE00>
# ['L', 20]
# None
# <__main__.TreeNode object at 0x00000264875CDAF0>
# ['M', 19]
# None
# <__main__.TreeNode object at 0x00000264875CE840>
# ['N', 24]
# None
# <__main__.TreeNode object at 0x00000264875CDEB0>
# ['O', 18]
# None
# <__main__.TreeNode object at 0x00000264875CFBF0>
# ['P', 13]
# None
# <__main__.TreeNode object at 0x00000264875CF470>
# ['Q', 1]
# None
# <__main__.TreeNode object at 0x00000264875CC830>
# ['R', 25]
# None
# <__main__.TreeNode object at 0x00000264875CC9B0>
# ['S', 35]
# None
# <__main__.TreeNode object at 0x00000264875CC380>
# ['T', 25]
# None
# <__main__.TreeNode object at 0x00000264875CD190>
# ['U', 15]
# None
# <__main__.TreeNode object at 0x00000264875CEB10>
# ['V', 5]
# None
# <__main__.TreeNode object at 0x00000264875CF350>
# ['W', 21]
# None
# <__main__.TreeNode object at 0x00000264875CEED0>
# ['X', 2]
# None
# <__main__.TreeNode object at 0x00000264875CCE90>
# ['Y', 8]
# None
# <__main__.TreeNode object at 0x00000264875CEF30>
# ['Z', 3]
# None
# None

# %%
x = process_input_file(r'../resources/FreqTable.txt', freq_table= True)
# Huffman_object = HuffmanEncoding(x)
# Huffman_object.create_priority_queue()

bst = BinarySearchTree(x)
bst.create_binary_search_tree()

#process_input_file(r'../resources/Encoded.txt', Encode= True)
# Out:
# [['A', 19], ['B', 16], ['C', 17], ['D', 11], ['E', 42], ['F', 12], ['G', 14], ['H', 17], ['I', 16], ['J', 5], ['K', 10], ['L', 20], ['M', 19], ['N', 24], ['O', 18], ['P', 13], ['Q', 1], ['R', 25], ['S', 35], ['T', 25], ['U', 15], ['V', 5], ['W', 21], ['X', 2], ['Y', 8], ['Z', 3]]
# 19
# 16
# 17
# 11
# 42
# 12
# 14
# 17
# 16
# 5
# 10
# 20
# 19
# 24
# 18
# 13
# 1
# 25
# 35
# 25
# 15
# 5
# 21
# 2
# 8
# 3
